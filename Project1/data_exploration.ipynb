# %%
import pandas as pd

from data_handling import MrozHandler
fp = "data/Mroz.csv"
mz = MrozHandler(fp)

print([col for col in mz.full.columns])
# Out:
# Full dataset shape
# Number of rows: 753
# Number of features: 22
# Working subset shape:
# Number of rows: 428
# Number of features: 22
# ['work', 'hoursw', 'kidslt6', 'child618', 'agew', 'educ', 'hearnw', 'wagew', 'hoursh', 'ageh', 'educh', 'wageh', 'income', 'motheduc', 'fatheduc', 'unemprate', 'city', 'exper', 'nwifeinc', 'exper_c', 'expersq', 'lwage']
